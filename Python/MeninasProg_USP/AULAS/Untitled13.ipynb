# %%
saldo = int(input())
item = 0

while True:
  valor_item = int(input())
  if valor_item < 0:
    break
  if valor_item > saldo:
    break
if valor_item < saldo:
    saldo2 = saldo - valor_item
    item += 1

    final = '%.2f' % saldo2
print(f'Número de itens {item}')
print(f'Saldo:{final}')
# Out:
# 100
# 50
# 30
# 30

# %%
# Carlos Drummond de Andrade 3
entrada = ''
tamanho = 0

while entrada != 'CDA 1942':
   entrada = input()
   if (entrada != '') and (entrada != 'CDA 1942'):
    tamanho += 1

print(tamanho)
