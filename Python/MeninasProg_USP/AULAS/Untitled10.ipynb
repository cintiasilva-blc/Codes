# %%
string = input()

for carc in string:
  num = int(carc)
  print('*' * num)
# Out:
# 908040
# *********
#
# ********
#
# ****

# %%
string = input()
num = []
for carc in string:
  if carc == string
  print(carc num)
