# %%
vl_disponivel = int(input())

# %%
dig1 = int(input())
dig2 = int(input())
dig3 = int(input())
dig4 = int(input())

num = dig1 * 1000 + dig2 * 100 + dig3 * 10 + dig4
dobro = num * 2

print(dobro)
# Out:
# 8
# 5
# 0
# 1
# 17002
