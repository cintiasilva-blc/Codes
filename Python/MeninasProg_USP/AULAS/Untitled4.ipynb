# %%
carac=input()

vogais='AEIOUaeiou'
algarismos='123456789'
carac_especiais='@#$%_()-+=&*'

if carac in vogais:
  print('vogal')
elif carac in algarismos:
  print('algarismo')
elif carac in carac_especiais:
  print('especial')
else:
   print('outro')
# Out:
# a
# vogal
